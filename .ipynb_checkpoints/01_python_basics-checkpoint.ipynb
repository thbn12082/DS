# %%
x = 10
y = 100
name = "thbn"
is_learning_DS = True

print(type(x), type(y), type(name), type(is_learning_DS))
# Out:
# <class 'int'> <class 'int'> <class 'str'> <class 'bool'>

# %%
scores = [8,9,10]
students = ["thbn", "dong", "ngoc"]

print(scores)
print(students)
print(len(scores))
# Out:
# [8, 9, 10]
# ['thbn', 'dong', 'ngoc']
# 3
